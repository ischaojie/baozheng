# %%
import pandas as pd

# %%
source = pd.read_csv("spam_message.txt", sep="\t", header=None, names=['category', 'head', 'detail'], )
source['id'] = source.index
source['marked'] = False
source
# Out:
#         category                                               head  detail  \
# 0              0                      商业秘密的秘密性那是维系其商业价值和垄断地位的前提条件之一     NaN
# 1              1  南口阿玛施新春第一批限量春装到店啦         春暖花开淑女裙、冰蓝色公主衫  ...     NaN
# 2              0                                   带给我们大常州一场壮观的视觉盛宴     NaN
# 3              0                                      有原因不明的泌尿系统结石等     NaN
# 4              0                                    23年从盐城拉回来的麻麻的嫁妆     NaN
# ...          ...                                                ...     ...
# 754838         0                                  助排毒缓解痛经预防子宫肌瘤&amp     NaN
# 754839         0                                   这是今年首次启动I级防台应急响应     NaN
# 754840         0                                     丽江下飞机时迎接我们的是凉风     NaN
# 754841         0                            费了半天劲各种找关系终于联系上心仪公司的内部人     NaN
# 754842         0                                    是汉奸还是被强奸自己对号入座吧     NaN
#
#             id  marked
# 0            0   False
# ...
